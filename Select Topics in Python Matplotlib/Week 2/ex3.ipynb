# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots()

x2=[43, 58, 16, 80, 57, 53, 18, 77, 4, 74, 5]
y2=[45, 52, 42, 69, 66, 67, 68, 24, 46, 12, 32]


# YOUR CODE HERE
plt.plot(x2,y2)
plt.title("Random Numbers 3")
plt.legend(["Numbers"])
plt.show()

# %% [markdown]
# ### The cell below shows the auto-grader code
# You can run the below cell to get feedback on your code.
#
# Alternatively, you can click the **Validate** button in the Jupyter tool bar.
# ![](Jupyter_Validate.png)

# %%
from plotchecker import LinePlotChecker
# Docs: https://plotchecker.readthedocs.io/en/latest/

pc = LinePlotChecker(ax)
pc.assert_num_lines(1)
pc.assert_x_data_equal([[43, 58, 16, 80, 57, 53, 18, 77, 4, 74, 5]])
pc.assert_y_data_equal([[45, 52, 42, 69, 66, 67, 68, 24, 46, 12, 32]])
pc.assert_title_equal('Random Numbers 3')
pc.assert_labels_equal(['Numbers'])

assert ax.legend_ != 'None'

print('All tests pass!')
# Out:
# All tests pass!

# %% [markdown]
# ![](Jupyter_Save.png)
